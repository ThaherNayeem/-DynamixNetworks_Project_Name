# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_heart = pd.read_csv('heart.csv')
df_heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df_heart = df_heart.drop_duplicates()

# %%
df_heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df_heart = df_heart.rename(columns ={"age":"Age",
    "sex":"Gender",
    "cp":"Chest Pain Type",
    "trestbps":"Resting Blood Pressure",
    "chol":"Serum Cholesterol",
    "fbs":"Fasting Blood Sugar",
    "restecg":"Resting ECG Results",
    "thalach":"Maximum Heart Rate",
    "exang":"Exercise-Induced Angina",
    "oldpeak":"ST Depression",
    "slope":"ST Segment Slope",
    "ca":"Number of Major Vessels",
    "thal":"Thalassemia Result",
    "target":"Heart Disease Presence"
                                    })

# %%
df_heart.head()
# Out:
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Serum Cholesterol  \
# 0   52       1                0                     125                212
# 1   53       1                0                     140                203
# 2   70       1                0                     145                174
# 3   61       1                0                     148                203
# 4   62       0                0                     138                294
#
#    Fasting Blood Sugar  Resting ECG Results  Maximum Heart Rate  \
# 0                    0                    1                 168
# 1                    1                    0                 155
# 2                    0                    1                 125
# 3                    0                    1                 161
# 4                    1                    1                 106
#
#    Exercise-Induced Angina  ST Depression  ST Segment Slope  \
# 0                        0            1.0                 2
# ...

# %%
# Demographic Features
--------------------------------------------------------------
# Age
# Gender

# %%
# Clinical / Medical Test Features
---------------------------------------------------------------
# Chest Pain Type

# Resting Blood Pressure

# Serum Cholesterol

# Fasting Blood Sugar

# Resting ECG Results

# Maximum Heart Rate

# Exercise-Induced Angina

# ST Depression (oldpeak) 

# ST Segment Slope (slope)

# Number of Major Vessels (ca)

# Thalassemia Result (thal)

# %%
# Target Variable
-----------------------------------------------------------------
# Heart Disease Presence (target)

# 1 = Yes

# 0 = No

# %%
# Exploratory Data Analysis (EDA)

df_heart.describe()
df_heart["Heart Disease Presence"].value_counts()
# Out:
# Heart Disease Presence
# Yes    164
# No     138
# Name: count, dtype: int64

# %%
# Histogram (Age)
plt.hist(df_heart["Age"], bins = 10)
plt.xlabel("Age")
plt.ylabel("Number of Patients")
plt.title("Age Distribution")
plt.show()

# %%
# Bar Chart (Gender vs Disease)
pd.crosstab(df_heart["Gender"], df_heart["Heart Disease Presence"]).plot(kind = "bar")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender VS Heart Disease")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize = (10,9))
sns.heatmap(df_heart.corr(numeric_only = True), annot = True, cmap = "coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Feature Analysis
df_heart.corr(numeric_only = True)
# Out:
#                               Age  Chest Pain Type  Resting Blood Pressure  \
# Age                      1.000000        -0.063107                0.283121
# Chest Pain Type         -0.063107         1.000000                0.046486
# Resting Blood Pressure   0.283121         0.046486                1.000000
# Serum Cholesterol        0.207216        -0.072682                0.125256
# Fasting Blood Sugar      0.119492         0.096018                0.178125
# Resting ECG Results     -0.111590         0.041561               -0.115367
# Maximum Heart Rate      -0.395235         0.293367               -0.048023
# Exercise-Induced Angina  0.093216        -0.392937                0.068526
# ST Depression            0.206040        -0.146692                0.194600
# ST Segment Slope        -0.164124         0.116854               -0.122873
# Number of Major Vessels  0.302261        -0.195356                0.099248
# ...

# %%
# Data Preprocessing
from sklearn.model_selection import train_test_split

X = df_heart.drop("Heart Disease Presence", axis = 1)
y = df_heart["Heart Disease Presence"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
df_heart = df_heart.dropna()

# %%
df_heart = df_heart.fillna(df_heart.mean())

# %%
X = df_heart.drop('Heart Disease Presence', axis=1)
y = df_heart['Heart Disease Presence']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Predictive Modeling
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression() 
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# Model Evaluation
from sklearn.metrics import accuracy_score

pred = model.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.7857142857142857
